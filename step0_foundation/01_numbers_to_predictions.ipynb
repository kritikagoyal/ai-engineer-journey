# %% [markdown]
# Goal: Understand how a machine learns by adjusting numbers — without using ML libraries.

# %%
import numpy as np

# %%
#Simple linear data y = 2*x + 1
X = np.array([0, 1, 2, 3, 4, 5], dtype=float)
y = 2*X + 1

# %%
w = np.random.randn()
b = np.random.randn()

print(f"Initial weight is {w}, and bias is {b}")
# Out:
# Initial weight is -0.548363804472523, and bias is 0.5349752850033891

# %%
def predict(X, w, b):
    return w * X + b

# %%
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)
