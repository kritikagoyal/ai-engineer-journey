# %% [markdown]
# # Dataset Utility Toolkit (Step 0)
# This notebook builds small, reusable utilities for:
# - loading datasets
# - handling missing values
# - splitting data
# - basic inspection
#
# Goal: understand what happens to data before any ML model sees it.

# %%
import pandas as pd
import numpy as np
import matplotllib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotllib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip3 install pandas
# Out:
#   Cell In[2], line 1
#     pip3 install pandas
#          ^
# SyntaxError: invalid syntax

# %%
# !pip3 install pandas numpy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 7.8 MB 3.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 249 kB 10.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.7 MB 8.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 113 kB 7.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 64 kB 5.0 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 2.9 MB 5.2 MB/s eta 0:00:01
# ...
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/Users/kritikagoyal/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import matplotllib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotllib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.5.1/libexec/bin/python

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !/opt/homebrew/Cellar/jupyterlab/4.5.1/libexec/bin/python -m pip install pandas numpy matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 8.8 MB/s  0:00:01.1 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]━━━━ 1/2 [pandas]
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_dataset(path):
    df = pd.read_csv(path)
    return df

# %%
df = load_dataset("shopping_behavior_updated.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
def inspect_dataset(df):
    print("Shape:", df.shape)
    print("\nColumns:", df.columns)
    print("\nMissing values:", df.isnull().sum())

# %%
inspect_dataset(df)
# Out:
# Shape: (3900, 18)
#
# Columns: Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')
#
# Missing values: Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
def fill_missing_with_mean(df):
    df_copy = df.copy()
    for col in df_copy.select_dtypes(include=np.number).columns:
        df_copy[col] = df_copy[col].fillna(df_copy[col].mean())
    return df_copy

# %%
df_clean = fill_missing_with_mean(df)
inspect_dataset(df_clean)
# Out:
# Shape: (3900, 18)
#
# Columns: Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')
#
# Missing values: Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
def train_test_split_manual(X, y, test_ratio=0.2, seed=42):
    np.random.seed(seed)
    indices = np.arange(len(X))

    test_size = int(len(indices) * test_ratio)
    test_indices = indices[:test_size]
    train_indices = indices[test_size:]

    return X[train_indices], X[test_indices], y[train_indices], y[test_indices]

# %%
def plot_feature(df, column):
    plt.figure()
    plt.hist(df[column], bins=30)
    plt.title(f"Distribution of {column}")
    plt.show()

# %% [markdown]
# ### What I learned
# - Data preparation is a first-class ML problem
# - Small utilities reduce cognitive load
# - Writing my own functions forced me to think about edge cases

# %%
x = np.arange(0, 10, 2)
x.shape
# Out:
# (5,)
